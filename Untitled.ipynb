# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in ./.nix-venv/lib/python3.12/site-packages (2.2.3)
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./.nix-venv/lib/python3.12/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.nix-venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.nix-venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.nix-venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (163 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in ./.nix-venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in ./.nix-venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 5.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.2 MB/s eta 0:00:006.3 MB/s eta 0:00:01
# Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 6.9 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0 pyparsing-3.2.0

# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("podcast_episodes_logos-podcast-with-jarrad-hope.csv")

# %%
df.columns
# Out:
# Index(['downloads_percent', 'downloads_total', 'episode_title', 'interval',
#        'published_at'],
#       dtype='object')

# %%
df
# Out:
#        downloads_percent  downloads_total  \
# 0                 0.0021             1804
# 1                 0.0018             1523
# 2                 0.0005              460
# 3                 0.0020             1763
# 4                 0.0033             2820
# ...                  ...              ...
# 71491             0.0000                0
# 71492             0.0000                0
# 71493             0.0000                0
# 71494             0.0000                0
# 71495             0.0000                0
#
#                                            episode_title    interval  \
# 0      Hashing It Out #85- Gauntlet.Network Tarun Chitra  2020-06-01
# 1        The Bitcoin Podcast #315- Overbit CEO Chieh Liu  2020-07-01
# 2      Hashing It Out #85- Gauntlet.Network Tarun Chitra  2020-07-01
# 3      The Bitcoin Podcast #314- Corey and Dee Just T...  2020-07-01
# 4      Hashing It Out #86- Ethereum Founder Vitalik B...  2020-07-01
# ...                                                  ...         ...
# 71491                    TBP03 - Bridging the Gender Gap  2024-10-01
# 71492                                 TBP10 - Bottoms Up  2024-10-01
# 71493                         TBP25 - The $199 Incentive  2024-10-01
# 71494                   TBP17 - Oiling the Squeaky Wheel  2024-10-01
# 71495                            TBP21 - Call For Papers  2024-10-01
#
#                published_at
# 0      2020-06-18 19:46:56Z
# 1      2020-07-20 16:00:04Z
# 2      2020-06-18 19:46:56Z
# 3      2020-07-13 16:00:08Z
# 4      2020-07-02 21:47:33Z
# ...                     ...
# 71491  2015-06-15 07:00:00Z
# 71492  2015-07-27 06:30:00Z
# 71493  2015-11-09 08:00:00Z
# 71494  2015-09-14 07:00:00Z
# 71495  2015-10-12 07:00:00Z
#
# [71496 rows x 5 columns]
